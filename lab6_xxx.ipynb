# %% [markdown]
# # Python程式設計與數據分析 LAB 6
#
# > Git and GitHub <br>
# > Streamlit <br>
# > Huggingface Space

# %% [markdown]
# 姓名 (Name):
#
# 學號 (Student ID):
#
# <span style="color:red">提醒：</span>上面的`姓名、學號`一定要用 **markdown** 語法填上去，漏寫會扣分。<br>
# 每個程式範例及練習題都要自己在 `Code` Cell 謄打及執行才會給分。

# %% [markdown]
# # Git & GitHub
#
# 課前：申請 [GitHub帳號](https://github.com/)

# %% [markdown]
# ## 基本概念說明及軟體安裝
# [Git 入門書](https://git-scm.com/book/zh-tw/v2)
# - ### [關於版本控制](https://git-scm.com/book/zh-tw/v2/%E9%96%8B%E5%A7%8B-%E9%97%9C%E6%96%BC%E7%89%88%E6%9C%AC%E6%8E%A7%E5%88%B6)
# - ### [Git 怎麼來的？](https://git-scm.com/book/zh-tw/v2/%E9%96%8B%E5%A7%8B-Git-%E7%9A%84%E7%B0%A1%E5%8F%B2)
# - ### [Git 基礎](https://git-scm.com/book/zh-tw/v2/%E9%96%8B%E5%A7%8B-Git-%E5%9F%BA%E7%A4%8E%E8%A6%81%E9%BB%9E)
# - ### [Git 安裝](https://git-scm.com/book/zh-tw/v2/%E9%96%8B%E5%A7%8B-Git-%E5%AE%89%E8%A3%9D%E6%95%99%E5%AD%B8)
#     - #### [Mac, 試試終端機 `git --version`，沒有再去安裝](https://git-scm.com/download/mac)
#     - #### [Windows, Git for Windows](https://git-scm.com/download/win)
# - ### [Git GUI client](https://git-scm.com/downloads/guis)
#     - #### [GitHub Desktop App](https://desktop.github.com/)
# - ### 個人資料設定 (`.gitconfig`)
#     - #### 命令列方法
#       ```bash
#       git config --global --edit
#       ```
#       開啟文字編輯器編修 `.gitconfig`，輸入 Github 註冊的姓名及 email 資料。
#       ```
#       [user]
#       name = XXX
#       email = xxx@xxx.xxx
#       ```
#     - #### 使用 GitHub Desktop
#
# ### 其他參考書
# - [Git 教學和 GitHub 設定指引](https://hackmd.io/@sysprog/git-with-github)
# - [Learning Git in 30 Days](https://github.com/doggy8088/Learn-Git-in-30-days/tree/master/zh-tw)

# %% [markdown]
# ## 基本操作練習

# %% [markdown]
# ### 從 Github 複製儲存庫到自己的帳號 (fork)
#
# [https://github.com/windyeh/tmupy_lab6_github](https://github.com/windyeh/tmupy_lab6_github)

# %% [markdown]
# ### 從 Github 複製儲存庫到自己的本機電腦 (clone)
#
# ```bash
# git clone https://github.com/windyeh/tmupy_lab6_github.git
# ```

# %% [markdown]
# ### 本機儲存庫更新 (add, commit)
#
# ```bash
# git add xxx
# git commit -m 'message about modification'
# ```

# %% [markdown]
# ### 將本機儲存庫上傳更新 GitHub 儲存庫 (push)
#
# ```bash
# git push
# ```

# %% [markdown]
# # JupyterLab 支援編修 py 檔語法提示及 Git
#
# ```bash
# conda create --name env-lab python=3.11 ipykernel jupyter jupyterlab numpy pandas nodejs
# pip install jupyter-lsp jedi-language-server jupyterlab-git
# ```

# %% [markdown]
# # Streamlit
#
# [Streamlit](streamlit.io) 是一個開源的 Python 框架，於2019年10月推出，作為應用程式中數據和使用者交互之間的媒介。其主要目標是讓資料科學家和機器學習工程師能夠在應用程式中創建和部署用於解釋資料分析結果的使用者界面（UI），而無需具備 Flask、Django、Node 等網頁開發工具的知識。Streamlit 框架使用 Python 語言和 API 來簡化在應用程式中部署內置對象的過程。
#
# Demo apps: <br>
# [monpa web demo version](https://nlptmu-monpaweb.hf.space/)<br>
# [Valence and Arousal](http://nlp.tmu.edu.tw:8081/)<br>
#
#
# 使用前要安裝套件：`pip install streamlit` <br>
# 將 python 程式寫於 `app.py` 檔，並執行 `streamlit run app.py` <br>
# Streamlit 的語法可以參考 [API 文件](https://docs.streamlit.io/library/api-reference)

# %% [markdown]
# ## 直接顯示整個 Dataframe
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
#
#
# st.title("家庭收支調查：縣市平均每人月消費")
# st.markdown('[資料來源：行政院主計總處家庭收支調查](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# st.dataframe(cost)
# ```

# %% [markdown]
# ## 選擇顯示縣市
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# columns = cost.columns
# options = st.multiselect('選擇想要顯示的縣市...', columns, default=["年別"])
# st.subheader(f'表1：民國 {cost["年別"].iloc[0]} 至 {cost["年別"].iloc[-1]} 年', divider='grey')
# #st.dataframe(cost[options])
# st.write(cost[options])
# st.divider()
# ```
#
# [Streamlit emoji shortcodes](https://streamlit-emoji-shortcodes-streamlit-app-gwckff.streamlit.app/)

# %% [markdown]
# ## 選擇顯示縣市及年別
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別"])
# year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (100, 101), step=1)
# year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# st.write(cost[cost["年別"].isin(year)][city])
# st.divider()
# ```

# %% [markdown]
# ## 選擇顯示縣市及年別 （分行排列）
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# col1, col2 = st.columns(2)
# with col1:
#     city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別"])
#
# with col2:
#     year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (100, 101), step=1)
#     year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# st.write(cost[cost["年別"].isin(year)][city])
# st.divider()
#
# ```

# %% [markdown]
# ## 長條圖
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# col1, col2 = st.columns(2)
# with col1:
#     city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "總平均"])
#
# with col2:
#     year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (100, 101), step=1)
#     year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# cost_select = cost[cost["年別"].isin(year)][city]
# st.write(cost_select)
# st.divider()
#
# # setup fonts for display mandarin characters
# font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
# font_manager.fontManager.addfont(font_file)
# matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
# st.pyplot(cost_select.plot(x='年別', kind='bar',title='長條圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# ```

# %% [markdown]
# ## 堆疊長條圖
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# col1, col2 = st.columns(2)
# with col1:
#     city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "總平均"])
#
# with col2:
#     year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (100, 101), step=1)
#     year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# cost_select = cost[cost["年別"].isin(year)][city]
# st.write(cost_select)
# st.divider()
#
# # setup fonts for display mandarin characters
# font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
# font_manager.fontManager.addfont(font_file)
# matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
# # 長條圖
# st.pyplot(cost_select.plot(x='年別', kind='bar',title='長條圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 堆疊長條圖
# st.pyplot(cost_select.plot(x='年別', kind='bar',title='堆疊長條圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# ```

# %% [markdown]
# ## 長條圖，面積圖，折線圖
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# col1, col2 = st.columns(2)
# with col1:
#     city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "新北市", "臺北市", "桃園市", "臺中市", "臺南市", "高雄市"])
#
# with col2:
#     year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (109, 111), step=1)
#     year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# cost_select = cost[cost["年別"].isin(year)][city]
# st.write(cost_select)
# st.divider()
#
# # setup fonts for display mandarin characters
# font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
# font_manager.fontManager.addfont(font_file)
# matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
# # 長條圖
# st.pyplot(cost_select.plot(x='年別', kind='bar',title='長條圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 堆疊長條圖
# st.pyplot(cost_select.plot(x='年別', kind='bar',title='堆疊長條圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 面積圖
# st.pyplot(cost_select.plot(x='年別', kind='area',title='面積圖', stacked=False).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 堆疊長條圖
# st.pyplot(cost_select.plot(x='年別', kind='area',title='堆疊面積圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 折線圖
# st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 折線圖，變換線條形式
# st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖-o', style='-o').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# # 折線圖，指定線條形式
# st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖，指定線題形式', style={"臺北市":"-."}).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# ```

# %% [markdown]
# ## 長條圖，面積圖，折線圖（排列顯示）
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# col1, col2 = st.columns(2)
# with col1:
#     city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "新北市", "臺北市", "桃園市", "臺中市", "臺南市", "高雄市"])
#
# with col2:
#     year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (109, 111), step=1)
#     year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# cost_select = cost[cost["年別"].isin(year)][city]
# st.write(cost_select)
# st.divider()
#
# # setup fonts for display mandarin characters
# font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
# font_manager.fontManager.addfont(font_file)
# matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
# col1, col2 = st.columns(2)
#
# # 長條圖
# with col1:
#     st.pyplot(cost_select.plot(x='年別', kind='bar',title='長條圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#
# # 堆疊長條圖
# with col2:
#     st.pyplot(cost_select.plot(x='年別', kind='bar',title='堆疊長條圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# col1, col2 = st.columns(2)
# # 面積圖
# with col1:
#     st.pyplot(cost_select.plot(x='年別', kind='area',title='面積圖', stacked=False).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#
# # 堆疊長條圖
# with col2:
#     st.pyplot(cost_select.plot(x='年別', kind='area',title='堆疊面積圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# col1, col2 = st.columns(2)
# # 折線圖
# with col1:
#     st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#
# # 折線圖，變換線條形式
# with col2:
#     st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖-o', style='-o').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
# st.divider()
#
# ```

# %% [markdown]
# ### Streamlit Chart
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
# col1, col2 = st.columns(2)
# with col1:
#     city = st.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "新北市", "臺北市", "桃園市", "臺中市", "臺南市", "高雄市"])
#
# with col2:
#     year_range = st.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (109, 111), step=1)
#     year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# cost_select = cost[cost["年別"].isin(year)][city]
# st.write(cost_select)
# st.divider()
#
# # setup fonts for display mandarin characters
# font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
# font_manager.fontManager.addfont(font_file)
# matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
#
# st.bar_chart(cost_select, x='年別')
# st.divider()
#
# st.line_chart(cost_select, x='年別')
# st.divider()
#
# ```

# %% [markdown]
# ### Sidebar
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
#
# st.sidebar.subheader('調整參數：')
# city = st.sidebar.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "新北市", "臺北市", "桃園市", "臺中市", "臺南市", "高雄市"])
# year_range = st.sidebar.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (109, 111), step=1)
# year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
# st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
# cost_select = cost[cost["年別"].isin(year)][city]
# st.write(cost_select)
# st.divider()
#
# # setup fonts for display mandarin characters
# font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
# font_manager.fontManager.addfont(font_file)
# matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
#
# st.bar_chart(cost_select, x='年別', )
# st.divider()
#
# st.line_chart(cost_select, x='年別')
# st.divider()
#
# ```

# %% [markdown]
# ### Click Button
#
# ```python
# import streamlit as st
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# from pylab import matplotlib
# from matplotlib import font_manager
#
#
# st.title(":flag-tw: 家庭收支調查")
# st.header(':grey[縣市每人平均月消費]', divider='rainbow')
# st.markdown('[*資料來源：行政院主計總處家庭收支調查*](https://www.stat.gov.tw/cp.aspx?n=3914)')
#
#
# cost = pd.read_csv('./dataset/cost.csv', encoding='utf-8')
#
# if 'clicked' not in st.session_state:
#     st.session_state.clicked = False
#
# def click_button():
#     st.session_state.clicked = True
#
# st.sidebar.subheader('調整參數：')
# city = st.sidebar.multiselect('選擇想要顯示的**縣市**...', cost.columns, default=["年別", "新北市", "臺北市", "桃園市", "臺中市", "臺南市", "高雄市"])
# year_range = st.sidebar.slider('選擇想要顯示的**年份**...', cost['年別'].unique()[0], cost['年別'].unique()[-1], (109, 111), step=1)
# year = [i for i in range(year_range[0], year_range[1]+1, 1)]
#
#
#
# st.button('點擊顯示圖表', on_click=click_button)
#
# if st.session_state.clicked:
#     st.subheader(f'表1：民國 {year_range[0]} 至 {year_range[1]} 年', divider='grey')
#     cost_select = cost[cost["年別"].isin(year)][city]
#     st.write(cost_select)
#     st.divider()
#
#     # setup fonts for display mandarin characters
#     font_file = "./fonts/jf-openhuninn-2.0.ttf"  # The path to the custom font file.
#     font_manager.fontManager.addfont(font_file)
#     matplotlib.rcParams['font.family'] = ['jf-openhuninn-2.0', 'sans-serif']
#
#
#     col1, col2 = st.columns(2)
#     # 長條圖
#     with col1:
#         st.pyplot(cost_select.plot(x='年別', kind='bar',title='長條圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#
#     # 堆疊長條圖
#     with col2:
#         st.pyplot(cost_select.plot(x='年別', kind='bar',title='堆疊長條圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#     st.divider()
#
#     col1, col2 = st.columns(2)
#     # 面積圖
#     with col1:
#         st.pyplot(cost_select.plot(x='年別', kind='area',title='面積圖', stacked=False).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#
#     # 堆疊長條圖
#     with col2:
#         st.pyplot(cost_select.plot(x='年別', kind='area',title='堆疊面積圖', stacked=True).legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#     st.divider()
#
#     col1, col2 = st.columns(2)
#     # 折線圖
#     with col1:
#         st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#
#     # 折線圖，變換線條形式
#     with col2:
#         st.pyplot(cost_select.plot(x='年別', kind='line',title='折線圖-o', style='-o').legend(bbox_to_anchor=(1.0, 1.0), fontsize='small').figure)
#     st.divider()
#
#     st.session_state.clicked = False
#
# ```

# %% [markdown]
# # Huggingface Space
#
# 課前：[申請 Huggingface 帳號](https://huggingface.co/)
#
# - 先去 huggingface 網站，並登入個人帳號。
# - 到 [https://huggingface.co/new-space](https://huggingface.co/new-space) 新增 Space APP。
# - 到 [https://huggingface.co/settings/tokens](https://huggingface.co/settings/tokens) 新增一個 Access Token
# - 本機資料夾，執行
#   ```bash
#   git lfs install
#   git clone https://USERNAME:YOUR_ACCESS_TOKEN@huggingface.co/spaces/USERNAME/REPO_NAME.git
#   cd REPO_NAME
#   git remote set-url origin https://USERNAME:YOUR_ACCESS_TOKEN@huggingface.co/spaces/USERNAME/REPO_NAME.git
#   ```

# %% [markdown]
# #### >>> 練習題 <<<
#
# 使用你在 Lab4 爬蟲回來的資料，或是去[政府開放資料平台 https://data.gov.tw/](https://data.gov.tw/)，[內政部人口統計資料 https://www.ris.gov.tw/app/portal/346](https://www.ris.gov.tw/app/portal/346) 找一個有興趣的資料集。以 Streamlit 做出資料分析網頁（需可選擇，輸入，調整參數後顯示資料，圖表）。
